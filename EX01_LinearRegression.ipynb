# %% [markdown]
# # Numpy 기본 함수를 활용한 5X5 항등행렬 출력

# %%
import numpy as np
np.eye(5)

# %% [markdown]
# # 2. Matplotlib을 이용한 데이터 플로팅

# %%
#import os
#print(os.getcwd())
#import csv
#with open('C:/Users/ljc_1/PycharmProjects/Coursera_ML_01/Data/ex1data1.txt', 'r', encoding='utf-8') as f:
#    for row in csv.DictReader(f):
#        print(row)
#f.close()
import pandas as pd
df = pd.read_csv(filepath_or_buffer='C:/Users/ljc_1/PycharmProjects/Coursera_ML_01/Data/ex1data1.txt', 
                 names=['Population', 'Profit'])
#print(df)
import matplotlib.pyplot as plt
plt.scatter(df['Population'], df['Profit'], color='r', marker='x')
plt.xlim(4, 24)
plt.ylim(-5, 25)
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.grid()
plt.show()
